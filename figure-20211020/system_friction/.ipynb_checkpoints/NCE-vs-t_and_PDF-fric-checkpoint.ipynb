# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from glob import glob


#import warnings
#warnings.filterwarnings('ignore')

# %%
def slice_time(CE_all):
    
    ''' This function return a list of array that contains the CE in each un-averaged run'''
    
    t_all = CE_all[:,0]
    CE_list = []
    
    i0 = 0
    i1 = 0
    
    for i in range(len(t_all)-1):
        if t_all[i+1] < t_all[i]:
            i1 = i+1
            CE_list.append(CE_all[i0:i1,:])
            i0 = i1
            
    return CE_list


def limit_rc(CE_in,rc):
    index_use = CE_in[:,3] * (1-CE_in[:,4]) <rc
    return CE_in[index_use,:]

# %%
## 
##  Read the data for damping runs
##

RH = (2e-5/3.)**(1./3.)
rc = 0.01*RH

can_CE0 = limit_rc(np.load('../data/can_CE0-2000.npy'),rc)

dd_t5 = limit_rc(np.load('../data/df_d5tx.npy'),rc)
dd_t6 = limit_rc(np.load('../data/df_d6tx.npy'),rc)

dt_t5 = limit_rc(np.load('../data/df_dxt5.npy'),rc)
dt_t6 = limit_rc(np.load('../data/df_dxt6.npy'),rc)

d_t5t5 = limit_rc(np.load('../data/df_d5t5.npy'),rc)
d_t6t6 = limit_rc(np.load('../data/df_d6t6.npy'),rc)

can_CE0_list = slice_time(can_CE0)

dd5_list = slice_time(dd_t5)
dd6_list = slice_time(dd_t6)

dt5_list = slice_time(dt_t5)
dt6_list = slice_time(dt_t6)

d5_list = slice_time(d_t5t5)
d6_list = slice_time(d_t6t6)

# %%
print(len(dd5_list))
# Out:
# 52

# %%
##
##  Plot the time evolution of number
##
plt.rcParams.update({'font.size':22})

fig,axs = plt.subplots(3,2, sharex=False, figsize=(12,12))
fig.subplots_adjust(hspace=0.1)
fig.subplots_adjust(wspace=0.0)


# parameters of the plot

nbins = 11
t_bins = np.linspace(0,500,nbins)
nw = 1./200.
lw = 3
aluse = 0.1


# CE0
Ncase = len(d6_list)
N_each = np.zeros(200)
for i in range(Ncase):
    N_each[i] = len(d6_list[i])

t_bins = np.linspace(0,np.max(N_each),nbins)

N_each_CE0, bin_out, bar_out = axs[0,1].hist(N_each, bins=t_bins, linewidth=lw,
            weights=N_each*0 + 1./200,density=False,cumulative=False,
            label=r'$i=0$',edgecolor='k',facecolor='b',orientation='horizontal')

Nmax0 = np.max(N_each)
axs[0,1].grid()
axs[0,1].set_axisbelow(True)



# CE1
Ncase = len(dt6_list)
N_each = np.zeros(200)
for i in range(Ncase):
    N_each[i] = len(dt6_list[i])

t_bins = np.linspace(0,np.max(N_each),nbins)
    
N_each_CE1, bin_out, bar_out = axs[1,1].hist(N_each, bins=t_bins, linewidth=lw,
            weights=N_each*0 + 1./200,density=False,cumulative=False,
            label=r'$i=0$',edgecolor='k',facecolor='g',orientation='horizontal')

Nmax1 = np.max(N_each)
axs[1,1].grid()
axs[1,1].set_axisbelow(True)


# CE2
Ncase = len(dd6_list)
N_each = np.zeros(200)
for i in range(Ncase):
    N_each[i] = len(dd6_list[i])

t_bins = np.linspace(0,np.max(N_each),nbins)
    
N_each_CE2, bin_out, bar_out = axs[2,1].hist(N_each, bins=t_bins, linewidth=lw,
            weights=N_each*0 + 1./200,density=False,cumulative=False,
            label=r'$i=0$',edgecolor='k',facecolor='r',orientation='horizontal')

Nmax2 = np.max(N_each)
axs[2,1].grid()
axs[2,1].set_axisbelow(True)



##
##  Set the labels
##











##
##  Plot the time evolution of number
##



# parameters of the plot

nbins = 4001
t_bins = np.linspace(1e1,1e5,nbins)
nw = 1./200.
lw = 5
aluse = 0.1


# CE0

for i in range(len(d6_list)):
    axs[0,0].hist(d6_list[i][:,0], bins=t_bins,linewidth=lw,density=False,cumulative=True,
                histtype='step',label=r'CE0',alpha=aluse)

Nt_CE0, bin_out, bar_out = axs[0,0].hist(d_t6t6[:,0], bins=t_bins,linewidth=lw,
            weights=d_t6t6[:,0]*0+nw,density=False,cumulative=True,histtype='step',
            label=r'$i=0$',color='k')
print(Nt_CE0[-1])

axs[0,0].grid()
axs[0,0].set_axisbelow(True)


nw = 1./200.

# CE1

for i in range(len(dt6_list)):
    axs[1,0].hist(dt6_list[i][:,0], bins=t_bins,linewidth=lw,density=False,cumulative=True,
                histtype='step',label=r'CE0',alpha=aluse)

Nt_CE1, bin_out, bar_out = axs[1,0].hist(dt_t6[:,0], bins=t_bins,linewidth=lw,
            weights=dt_t6[:,0]*0+nw,density=False,cumulative=True,histtype='step',
            label=r'$i=0$',color='k')
print(Nt_CE1[-1])

axs[1,0].grid()
axs[1,0].set_axisbelow(True)


# CE0

for i in range(len(dd6_list)):
    axs[2,0].hist(dd6_list[i][:,0], bins=t_bins,linewidth=lw,density=False,cumulative=True,
                histtype='step',label=r'CE0',alpha=aluse)

Nt_CE2, bin_out, bar_out = axs[2,0].hist(dd_t6[:,0], bins=t_bins,linewidth=lw,
            weights=dd_t6[:,0]*0+nw,density=False,cumulative=True,histtype='step',
            label=r'$i=0$',color='k')
print(Nt_CE2[-1])

axs[2,0].grid()
axs[2,0].set_axisbelow(True)


##
##  Set the labels
##

axs[2,0].set_xlabel(r'$t$ [$P_1$]')
axs[1,0].set_ylabel(r'Number of CE2 encounters')

axs[2,1].set_xlabel(r'$N_0$ [orbit]')
axs[2,1].set_xlabel(r'Probability')





axs[0,0].set_xlim([1e0,0.99e5])
axs[1,0].set_xlim([1e0,0.99e5])
axs[2,0].set_xlim([1e0,0.99e5])

axs[0,1].set_xlim([0,0.65])
axs[1,1].set_xlim([0,0.65])
axs[2,1].set_xlim([0,0.65])





axs[0,0].set_ylim([0,Nmax0])
axs[1,0].set_ylim([0,Nmax1])
axs[2,0].set_ylim([0,Nmax2])

axs[0,1].set_ylim([0,Nmax0])
axs[1,1].set_ylim([0,Nmax1])
axs[2,1].set_ylim([0,Nmax2])




axs[0,0].set_xticks([4e4,8e4])
axs[1,0].set_xticks([4e4,8e4])
axs[2,0].set_xticks([4e4,8e4])

axs[0,1].set_xticks(np.linspace(0.2,0.60,3))
axs[1,1].set_xticks(np.linspace(0.2,0.60,3))
axs[2,1].set_xticks(np.linspace(0.2,0.60,3))





axs[0,0].set_xticklabels([])
axs[1,0].set_xticklabels([])

axs[0,1].set_xticklabels([])
axs[1,1].set_xticklabels([])






axs[0,0].text(0.03, 0.75,r'$\tau_{\rm drag}=\tau_{\rm trap}=10^6P_1$', ha='left', va='center', transform=axs[0,0].transAxes)
axs[1,0].text(0.03, 0.75,r'$\tau_{\rm trap}=10^6P_1$', ha='left', va='center', transform=axs[1,0].transAxes)
axs[2,0].text(0.03, 0.75,r'$\tau_{\rm damp}=10^6P_1$', ha='left', va='center', transform=axs[2,0].transAxes)

axs[0,1].text(0.7, 0.75,r'$N_2(t=10^5P_1)$', ha='center', va='center', transform=axs[0,1].transAxes)
axs[1,1].text(0.7, 0.75,r'$N_2(t=10^5P_1)$', ha='center', va='center', transform=axs[1,1].transAxes)
axs[2,1].text(0.7, 0.75,r'$N_2(t=10^5P_1)$', ha='center', va='center', transform=axs[2,1].transAxes)


##  Save the figure

plt.savefig('./pics/pics-NCE-disk.pdf',bbox_inches='tight',transparent=True)
plt.savefig('./pics/pics-NCE-disk.png',bbox_inches='tight',transparent=True)
# Out:
# 2.639999999999965
# 2.0899999999999763
# 1.6949999999999847

# %%
plt.rcParams.update({'font.size':22})

fig,axs = plt.subplots(1,3, sharey=True, figsize=(12,12))
fig.subplots_adjust(hspace=0.1)
fig.subplots_adjust(wspace=0.0)

lw=3
t_bin = np.linspace(5,15,5)

Ncase = len(dd6_list)
N_each = np.zeros(200)
for i in range(Ncase):
    N_each[i] = len(dd6_list[i])
axs[0].hist(N_each, linewidth=lw,weights=N_each*0 + 1./200,density=False,cumulative=False,histtype='step',edgecolor='k')

Ncase = len(dd5_list)
N_each = np.zeros(200)
for i in range(Ncase):
    N_each[i] = len(dd5_list[i])
axs[0].hist(N_each, linewidth=lw,weights=N_each*0 + 1./200,density=False,cumulative=False,histtype='step',edgecolor='r')



Ncase = len(dt6_list)
N_each = np.zeros(200)
for i in range(Ncase):
    N_each[i] = len(dt6_list[i])
axs[1].hist(N_each, linewidth=lw,weights=N_each*0 + 1./200,density=False,cumulative=False,histtype='step',edgecolor='k')

Ncase = len(dt5_list)
N_each = np.zeros(200)
for i in range(Ncase):
    N_each[i] = len(dt5_list[i])
axs[1].hist(N_each, linewidth=lw,weights=N_each*0 + 1./200,density=False,cumulative=False,histtype='step',edgecolor='g')



Ncase = len(d6_list)
N_each = np.zeros(200)
for i in range(Ncase):
    N_each[i] = len(d6_list[i])
axs[2].hist(N_each, linewidth=lw,weights=N_each*0 + 1./200,density=False,cumulative=False,histtype='step',edgecolor='k')

Ncase = len(d5_list)
N_each = np.zeros(200)
for i in range(Ncase):
    N_each[i] = len(d5_list[i])
axs[2].hist(N_each, linewidth=lw,weights=N_each*0 + 1./200,density=False,cumulative=False,histtype='step',edgecolor='b')
# Out:
# (array([0.505, 0.085, 0.135, 0.12 , 0.095, 0.035, 0.   , 0.005, 0.015,
#         0.005]),
#  array([0. , 0.9, 1.8, 2.7, 3.6, 4.5, 5.4, 6.3, 7.2, 8.1, 9. ]),
#  <a list of 1 Patch objects>)

# %%
plt.rcParams.update({'font.size':22})

fig,axs = plt.subplots(1,1, sharey=True, figsize=(12,12))
fig.subplots_adjust(hspace=0.1)
fig.subplots_adjust(wspace=0.0)

lw=3
t_bin = np.linspace(0,15,6)

Ncase = len(dd6_list)
N_each = np.zeros(200)
for i in range(Ncase):
    N_each[i] = len(dd6_list[i])
axs.hist(N_each, linewidth=lw,weights=N_each*0 + 1./200,density=False,cumulative=False,histtype='step',edgecolor='r',orientation='horizontal')

Ncase = len(dd5_list)
N_each = np.zeros(200)
for i in range(Ncase):
    N_each[i] = len(dd5_list[i])
axs.hist(N_each, linewidth=lw,weights=N_each*0 + 1./200,density=False,cumulative=False,histtype='step',edgecolor='r',ls='--',orientation='horizontal')



Ncase = len(dt6_list)
N_each = np.zeros(200)
for i in range(Ncase):
    N_each[i] = len(dt6_list[i])
axs.hist(N_each, linewidth=lw,weights=N_each*0 + 1./200,density=False,cumulative=False,histtype='step',edgecolor='g',orientation='horizontal')

Ncase = len(dt5_list)
N_each = np.zeros(200)
for i in range(Ncase):
    N_each[i] = len(dt5_list[i])
axs.hist(N_each, linewidth=lw,weights=N_each*0 + 1./200,density=False,cumulative=False,histtype='step',edgecolor='g',ls='--',orientation='horizontal')



Ncase = len(d6_list)
N_each = np.zeros(200)
for i in range(Ncase):
    N_each[i] = len(d6_list[i])
axs.hist(N_each, linewidth=lw,weights=N_each*0 + 1./200,density=False,cumulative=False,histtype='step',edgecolor='b',orientation='horizontal')

Ncase = len(d5_list)
N_each = np.zeros(200)
for i in range(Ncase):
    N_each[i] = len(d5_list[i])
axs.hist(N_each, linewidth=lw,weights=N_each*0 + 1./200,density=False,cumulative=False,histtype='step',edgecolor='b',ls='--',orientation='horizontal')


#axs.set_xlim([0.,0.2])
axs.set_ylim([0,15])

axs.set_xlabel('Probability')
axs.set_ylabel('Number of CE2 events')

plt.savefig('./pics/pics-NCE-disk-pdf.pdf',bbox_inches='tight',transparent=True)
plt.savefig('./pics/pics-NCE-disk-pdf.png',bbox_inches='tight',transparent=True)

# %%
from scipy.optimize import curve_fit

def Nt(t, T0, beta):
    return (t/T0)**beta

t_mid = 0.5*(t_bins[1:]+t_bins[:-1])

popt, pcov = curve_fit(Nt, t_mid, Nt_CE0, p0=np.array([Nt_CE0[-1]/t_mid[-1],0.55]))
print(Nt_CE0[-1])
print(popt)
plt.loglog(t_mid,Nt_CE0,'b')
plt.loglog(t_mid,Nt(t_mid,popt[0],popt[1]),'b--')

popt, pcov = curve_fit(Nt, t_mid, Nt_CE1, p0=np.array([Nt_CE1[-1]/t_mid[-1],0.55]))
print(Nt_CE1[-1])
print(popt)
plt.loglog(t_mid,Nt_CE1,'r')
plt.loglog(t_mid,Nt(t_mid,popt[0],popt[1]),'r--')

popt, pcov = curve_fit(Nt, t_mid, Nt_CE2, p0=np.array([Nt_CE2[-1]/t_mid[-1],0.55]))
print(Nt_CE2[-1])
print(popt)
plt.loglog(t_mid,Nt_CE2,'g')
plt.loglog(t_mid,Nt(t_mid,popt[0],popt[1]),'g--')
# Out:
# 123.78849999990786
# [5.29312722 0.49183642]
# 21.298999999995065
# [288.22297244   0.52540409]
# 2.541500000000042
# [1.73476501e+04 5.37925043e-01]

# %%
print(len(can_CE0[:,0])*nw)
print(len(can_CE1[:,0])*nw)
print(len(can_CE2[:,0])*nw)

Ni0 = np.zeros(len(can_CE0_list))
for i in range(len(can_CE0_list)):
    Ni = len(can_CE0_list[i][:,0])
    Ni0[i] = Ni
print(np.std(Ni0))

Ni1 = np.zeros(len(can_CE1_list))
for i in range(len(can_CE1_list)):
    Ni = len(can_CE1_list[i][:,0])
    Ni1[i] = Ni
print(np.std(Ni1))

Ni2 = np.zeros(len(can_CE2_list))
for i in range(len(can_CE2_list)):
    Ni = len(can_CE2_list[i][:,0])
    Ni2[i] = Ni
print(np.std(Ni2))
# Out:
# 124.395
# 21.5765
# 2.619
# 93.94067459235299
# 17.631098688304125
# 3.224408344389392

# %%
t_mid = np.logspace(1,8,10)
plt.loglog(t_mid,(t_mid/1.73476501e+04)**5.37925043e-01)
plt.loglog(t_mid,(t_mid/1.76469312e+04)**5.24342911e-01)
